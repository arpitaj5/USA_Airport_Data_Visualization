# %%
import pandas as pd
import numpy as np
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
from datetime import datetime
import pandas_datareader.data as web
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pd.read_csv("/Users/leesa/Downloads/airport.csv")
df = data[['Origin_state', 'Passengers', 'Fly_date', 'Year']]
df = df.groupby(['Origin_state', 'Fly_date', 'Year'])['Passengers'].sum().reset_index()
df = df.groupby(['Origin_state', 'Year'])['Passengers'].mean().reset_index()

# %%
data1 = []

for state in df['Origin_state'].drop_duplicates():
    data1.append(go.Scatter(x=df[df['Origin_state'] == state]['Year'].values.tolist(),
                        y=df[df['Origin_state'] == state]['Passengers'].values.tolist(),
                        name= state,
                       visible=False,
                       #text = df[df['Origin_state'] == state]['Passengers'].values.tolist(),
                       #textposition='auto'
                        ))

buttons = []

for row, state in df.Origin_state.drop_duplicates().reset_index()['Origin_state'].iteritems():
    condition = [False]*len(df.Origin_state.drop_duplicates())
    condition[row] = True
    buttons.append(dict(label = state,
                 method = 'update',
                 args = [{'visible': condition},
                         {'title': 'Trend across the years in : ' + state,
                          }]))

updatemenus=list([
    dict(
        buttons = buttons,
        pad = {'r': 0, 't': 10},
        #x = 0.1,
        #xanchor = 'left',
       # y = 1.0,
        yanchor = 'top',
        bgcolor = 'AAAAAA',
        active = 99,
        bordercolor = '#FFFFFF',
        font = dict(size=11, color='#000000'))])

layout = dict(title='Trend across the years', showlegend=False,
              updatemenus=updatemenus)

figure = dict(data=data1, layout=layout)
#plotly.offline.plot(figure)
iplot(figure)
# Out:
# <div id="1573ab3e-71b2-4821-8c93-adddf973535c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1573ab3e-71b2-4821-8c93-adddf973535c", [{"y": [197716.33333333334, 197246.08333333334, 208416.41666666666, 205828.08333333334, 221796.33333333334, 224446.83333333334, 224275.5, 230588.5, 224648.83333333334, 208444.25], "visible": false, "type": "scatter", "name": "AK", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [233959.16666666666, 215669.83333333334, 204549.08333333334, 222401.83333333334, 237970.08333333334, 240847.66666666666, 223444.25, 236863.75, 235359.91666666666, 211533.66666666666], "visible": false, "type": "scatter", "name": "AL", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [139017.83333333334, 133486.25, 128524.0, 136308.41666666666, 147661.41666666666, 160733.41666666666, 157760.41666666666, 162434.25, 154253.66666666666, 143663.91666666666], "visible": false, "type": "scatter", "name": "AR", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [1513817.3333333333, 1434636.75, 1396984.8333333333, 1531101.25, 1616146.25, 1685192.8333333333, 1687455.8333333333, 1712301.0, 1622381.5, 1532344.0], "visible": false, "type": "scatter", "name": "AZ", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [5084735.916666667, 4665582.916666667, 4415798.0, 4547331.333333333, 4914115.916666667, 5017435.0, 5012470.5, 5192987.416666667, 4921481.75, 4685129.75], "visible": false, "type": "scatter", "name": "CA", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [74984.66666666667, 65895.0, 65343.083333333336, 78897.75, 79495.33333333333, 81087.25, 80801.75, 82938.25, 76660.58333333333, 70114.33333333333], "visible": false, "type": "scatter", "name": "CO", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [285326.5833333333, 267147.25, 252405.91666666666, 253034.66666666666, 272216.4166666667, 295756.6666666667, 277215.6666666667, 259066.66666666666, 241621.75, 215315.58333333334], "visible": false, "type": "scatter", "name": "CT", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [1041492.75, 870941.4166666666, 857875.4166666666, 1015428.6666666666, 1270839.0, 1502103.3333333333, 1352769.8333333333, 1396494.6666666667, 1332891.0833333333, 1296668.4166666667], "visible": false, "type": "scatter", "name": "DC", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [0.0, 71.4, 65.0, 201.0, 172.6, 170.9090909090909, 887.7, 979.0833333333334, 105.0, 63.333333333333336], "visible": false, "type": "scatter", "name": "DE", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [3409797.0833333335, 3303081.5, 3259567.0, 3396938.3333333335, 3755637.0833333335, 4034347.25, 4010012.8333333335, 4064983.3333333335, 3941691.5833333335, 3722350.8333333335], "visible": false, "type": "scatter", "name": "FL", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [2857485.5, 2669058.5833333335, 2720980.25, 2813940.5, 2974454.5, 3037739.25, 2923496.6666666665, 3031133.8333333335, 3063138.5, 2964298.1666666665], "visible": false, "type": "scatter", "name": "GA", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [780591.0, 719452.75, 696193.8333333334, 688959.75, 718879.75, 747577.6666666666, 761441.0833333334, 815123.8333333334, 694077.1666666666, 678763.0], "visible": false, "type": "scatter", "name": "HI", "x": [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]}, {"y": [102375.33333333333, 95836.25, 100263.33333333333, 115137.33333333333, 119525.91666666667, 116534.75, 120050.41666666667, 120100.83333333333, 114250.41666666667, 104689.25], "visible": false, "type": "scatter", "name": "IA", "x": [2000, 2001,  ...

# %%
data1
# Out:
# [{'name': 'AK',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [197716.33333333334,
#    197246.08333333334,
#    208416.41666666666,
#    205828.08333333334,
#    221796.33333333334,
#    224446.83333333334,
#    224275.5,
#    230588.5,
#    224648.83333333334,
#    208444.25]},
#  {'name': 'AL',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [233959.16666666666,
#    215669.83333333334,
#    204549.08333333334,
#    222401.83333333334,
#    237970.08333333334,
#    240847.66666666666,
#    223444.25,
#    236863.75,
#    235359.91666666666,
#    211533.66666666666]},
#  {'name': 'AR',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [139017.83333333334,
#    133486.25,
#    128524.0,
#    136308.41666666666,
#    147661.41666666666,
#    160733.41666666666,
#    157760.41666666666,
#    162434.25,
#    154253.66666666666,
#    143663.91666666666]},
#  {'name': 'AZ',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [1513817.3333333333,
#    1434636.75,
#    1396984.8333333333,
#    1531101.25,
#    1616146.25,
#    1685192.8333333333,
#    1687455.8333333333,
#    1712301.0,
#    1622381.5,
#    1532344.0]},
#  {'name': 'CA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [5084735.916666667,
#    4665582.916666667,
#    4415798.0,
#    4547331.333333333,
#    4914115.916666667,
#    5017435.0,
#    5012470.5,
#    5192987.416666667,
#    4921481.75,
#    4685129.75]},
#  {'name': 'CO',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [74984.66666666667,
#    65895.0,
#    65343.083333333336,
#    78897.75,
#    79495.33333333333,
#    81087.25,
#    80801.75,
#    82938.25,
#    76660.58333333333,
#    70114.33333333333]},
#  {'name': 'CT',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [285326.5833333333,
#    267147.25,
#    252405.91666666666,
#    253034.66666666666,
#    272216.4166666667,
#    295756.6666666667,
#    277215.6666666667,
#    259066.66666666666,
#    241621.75,
#    215315.58333333334]},
#  {'name': 'DC',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [1041492.75,
#    870941.4166666666,
#    857875.4166666666,
#    1015428.6666666666,
#    1270839.0,
#    1502103.3333333333,
#    1352769.8333333333,
#    1396494.6666666667,
#    1332891.0833333333,
#    1296668.4166666667]},
#  {'name': 'DE',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [0.0,
#    71.4,
#    65.0,
#    201.0,
#    172.6,
#    170.9090909090909,
#    887.7,
#    979.0833333333334,
#    105.0,
#    63.333333333333336]},
#  {'name': 'FL',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [3409797.0833333335,
#    3303081.5,
#    3259567.0,
#    3396938.3333333335,
#    3755637.0833333335,
#    4034347.25,
#    4010012.8333333335,
#    4064983.3333333335,
#    3941691.5833333335,
#    3722350.8333333335]},
#  {'name': 'GA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [2857485.5,
#    2669058.5833333335,
#    2720980.25,
#    2813940.5,
#    2974454.5,
#    3037739.25,
#    2923496.6666666665,
#    3031133.8333333335,
#    3063138.5,
#    2964298.1666666665]},
#  {'name': 'HI',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [780591.0,
#    719452.75,
#    696193.8333333334,
#    688959.75,
#    718879.75,
#    747577.6666666666,
#    761441.0833333334,
#    815123.8333333334,
#    694077.1666666666,
#    678763.0]},
#  {'name': 'IA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [102375.33333333333,
#    95836.25,
#    100263.33333333333,
#    115137.33333333333,
#    119525.91666666667,
#    116534.75,
#    120050.41666666667,
#    120100.83333333333,
#    114250.41666666667,
#    104689.25]},
#  {'name': 'ID',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [4368.5,
#    4956.666666666667,
#    8887.916666666666,
#    18750.833333333332,
#    20120.333333333332,
#    21779.333333333332,
#    20120.083333333332,
#    19924.333333333332,
#    18131.583333333332,
#    17831.666666666668]},
#  {'name': 'IL',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [2832712.0,
#    2673199.3333333335,
#    2739167.0,
#    2975261.5833333335,
#    3223341.0,
#    3174431.75,
#    3207074.3333333335,
#    3185161.4166666665,
#    2903226.0,
#    2746452.5]},
#  {'name': 'IN',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [358802.5833333333,
#    330631.0,
#    322116.0,
#    360140.4166666667,
#    388336.0833333333,
#    401249.3333333333,
#    391730.5833333333,
#    393213.25,
#    378571.1666666667,
#    340488.3333333333]},
#  {'name': 'KS',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [38696.25,
#    34419.333333333336,
#    36231.083333333336,
#    52798.416666666664,
#    56164.416666666664,
#    55683.833333333336,
#    54801.916666666664,
#    58784.083333333336,
#    56373.25,
#    52459.583333333336]},
#  {'name': 'KY',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [37630.333333333336,
#    30616.666666666668,
#    34836.25,
#    51564.333333333336,
#    51457.5,
#    47966.083333333336,
#    44774.0,
#    45397.833333333336,
#    43066.583333333336,
#    38681.5]},
#  {'name': 'LA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [529851.6666666666,
#    496469.3333333333,
#    474146.8333333333,
#    485560.5,
#    507153.8333333333,
#    435697.8333333333,
#    367940.4166666667,
#    423612.9166666667,
#    428609.8333333333,
#    412075.3333333333]},
#  {'name': 'MA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [854874.4166666666,
#    735110.6666666666,
#    710296.8333333334,
#    730767.25,
#    829951.1666666666,
#    856565.1666666666,
#    889380.5833333334,
#    906255.25,
#    845357.0833333334,
#    840728.75]},
#  {'name': 'MD',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [721661.4166666666,
#    749941.0833333334,
#    705227.4166666666,
#    744662.5833333334,
#    769382.1666666666,
#    752388.3333333334,
#    792010.3333333334,
#    809925.9166666666,
#    789952.4166666666,
#    798711.0]},
#  {'name': 'ME',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [49743.0,
#    56928.083333333336,
#    59769.416666666664,
#    70616.0,
#    77914.16666666667,
#    83053.58333333333,
#    78177.16666666667,
#    86322.16666666667,
#    89479.5,
#    89855.08333333333]},
#  {'name': 'MI',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [1406763.8333333333,
#    1278383.0,
#    1264947.3333333333,
#    1341450.9166666667,
#    1437030.3333333333,
#    1466151.5,
#    1444924.25,
#    1425565.8333333333,
#    1366068.5,
#    1251693.6666666667]},
#  {'name': 'MN',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [

#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [523422.75,
#    487252.8333333333,
#    476987.8333333333,
#    494359.6666666667,
#    518543.9166666667,
#    553311.6666666666,
#    562997.5,
#    590979.25,
#    570474.25,
#    519071.8333333333]},
#  {'name': 'PA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [1587551.25,
#    1520764.0833333333,
#    1469730.3333333333,
#    1486807.75,
#    1587693.5833333333,
#    1602334.75,
#    1581536.3333333333,
#    1602586.0833333333,
#    1542936.0,
#    1464608.0833333333]},
#  {'name': 'RI',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [209372.91666666666,
#    209950.08333333334,
#    206114.33333333334,
#    211016.75,
#    224528.58333333334,
#    231831.58333333334,
#    212600.58333333334,
#    204680.66666666666,
#    193963.41666666666,
#    178563.0]},
#  {'name': 'SC',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [205052.0,
#    180190.08333333334,
#    178349.66666666666,
#    224897.33333333334,
#    260340.08333333334,
#    294480.3333333333,
#    258088.91666666666,
#    282814.3333333333,
#    270393.25,
#    250657.5]},
#  {'name': 'SD',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [33754.416666666664,
#    31020.0,
#    28535.666666666668,
#    37119.0,
#    40550.583333333336,
#    43504.583333333336,
#    42530.833333333336,
#    44599.666666666664,
#    42190.166666666664,
#    38500.083333333336]},
#  {'name': 'TN',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [890834.1666666666,
#    822177.25,
#    788297.1666666666,
#    853612.3333333334,
#    873669.8333333334,
#    922766.5833333334,
#    923059.25,
#    936283.75,
#    893682.75,
#    841628.9166666666]},
#  {'name': 'TX',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [4818128.583333333,
#    4475242.166666667,
#    4232640.666666667,
#    4250168.416666667,
#    4631464.583333333,
#    4781279.333333333,
#    5026353.833333333,
#    5125967.416666667,
#    4950741.25,
#    4755373.666666667]},
#  {'name': 'UT',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [676175.0,
#    611309.0,
#    600426.5833333334,
#    679317.0,
#    669908.75,
#    796476.5,
#    740696.4166666666,
#    758198.8333333334,
#    714229.0,
#    708896.75]},
#  {'name': 'VA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [123724.16666666667,
#    108279.16666666667,
#    111416.75,
#    141888.66666666666,
#    150831.25,
#    170982.83333333334,
#    185749.91666666666,
#    200276.91666666666,
#    189937.16666666666,
#    184490.58333333334]},
#  {'name': 'VT',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [23290.0,
#    30735.416666666668,
#    36077.166666666664,
#    45515.666666666664,
#    52463.25,
#    57796.416666666664,
#    56602.916666666664,
#    58718.25,
#    62614.166666666664,
#    58550.416666666664]},
#  {'name': 'WA',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [1104733.0833333333,
#    1049712.5833333333,
#    1041956.5,
#    1049337.5,
#    1124005.1666666667,
#    1142889.9166666667,
#    1170479.1666666667,
#    1230528.75,
#    1238462.1666666667,
#    1193027.8333333333]},
#  {'name': 'WI',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [345299.4166666667,
#    319359.5,
#    319813.0,
#    380443.5833333333,
#    402891.6666666667,
#    424544.8333333333,
#    430070.5833333333,
#    437250.9166666667,
#    433027.8333333333,
#    438855.0833333333]},
#  {'name': 'WV',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [12568.0,
#    9826.666666666666,
#    13246.75,
#    23484.25,
#    28256.583333333332,
#    30390.583333333332,
#    25351.916666666668,
#    23826.75,
#    22735.166666666668,
#    22350.5]},
#  {'name': 'WY',
#   'type': 'scatter',
#   'visible': False,
#   'x': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
#   'y': [4192.75,
#    4060.0833333333335,
#    7656.0,
#    15577.916666666666,
#    13784.083333333334,
#    18050.833333333332,
#    19252.833333333332,
#    17829.75,
#    20256.916666666668,
#    20091.916666666668]}]
