# %%
import pandas as pd
import numpy as np
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
from datetime import datetime
import pandas_datareader.data as web
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pd.read_csv("/Users/leesa/Downloads/Viz_project/airport.csv")

# %%
df = data[['Origin_state', 'Passengers', 'Origin_city', 'Fly_date']]
df = df.groupby(['Origin_state', 'Origin_city', 'Fly_date'])['Passengers'].sum().reset_index()
df = df.groupby(['Origin_state', 'Origin_city'])['Passengers'].mean().reset_index()
df.head()
# Out:
#   Origin_state Origin_city     Passengers
# 0           AK   Anchorage  146458.116667
# 1           AK   Fairbanks   30343.366667
# 2           AK      Juneau   19624.366667
# 3           AK   Ketchikan   13099.966667
# 4           AK      Kodiak    4814.900000

# %%
df2 = data[['Destination_state', 'Passengers', 'Destination_city', 'Fly_date']]
df2 = df2.groupby(['Destination_state', 'Destination_city', 'Fly_date'])['Passengers'].sum().reset_index()
df2 = df2.groupby(['Destination_state', 'Destination_city'])['Passengers'].mean().reset_index()

# %%
data1 = []

for state in df['Origin_state'].drop_duplicates():
    data1.append(go.Bar(x=df[df['Origin_state'] == state]['Origin_city'].values.tolist(),
                        y=df[df['Origin_state'] == state]['Passengers'].values.tolist(),
                        name= state,
                       visible=False,
                       #text = df[df['Origin_state'] == state]['Passengers'].values.tolist(),
                       #textposition='auto'
                        ))

buttons = []

for row, state in df.Origin_state.drop_duplicates().reset_index()['Origin_state'].iteritems():
    condition = [False]*len(df.Origin_state.drop_duplicates())
    condition[row] = True
    buttons.append(dict(label = state,
                 method = 'update',
                 args = [{'visible': condition},
                         {'title': 'Trend across the years in : ' + state,
                          }]))

updatemenus=list([
    dict(
        buttons = buttons,
        pad = {'r': 0, 't': 10},
        #x = 0.1,
        #xanchor = 'left',
       # y = 1.0,
        yanchor = 'top',
        bgcolor = 'AAAAAA',
        active = 99,
        bordercolor = '#FFFFFF',
        font = dict(size=11, color='#000000'))])

layout = dict(title='Average travellers per airport', showlegend=False,
              updatemenus=updatemenus)

figure = dict(data=data1, layout=layout)
#plotly.offline.plot(figure)
plot(figure, filename='airports_bar')
# Out:
# 'file:///Users/leesa/Downloads/Viz_project/airports_bar.html'

# %%
trace0 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2015']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2015']['IncidntNum_Count'],
    mode = 'lines',
    name = '2015'
)
                                           
trace1 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2014']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2014']['IncidntNum_Count'],
    mode = 'lines',
    name = '2014'
)

trace2 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2013']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2013']['IncidntNum_Count'],
    mode = 'lines',
    name = '2013'
)
                                           
trace3 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2012']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2012']['IncidntNum_Count'],
    mode = 'lines',
    name = '2012'
)
                                           
trace4 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2011']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2011']['IncidntNum_Count'],
    mode = 'lines',
    name = '2011'
)

trace5 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2010']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2010']['IncidntNum_Count'],
    mode = 'lines',
    name = '2010'
)

data = [trace0, trace1, trace2, trace3, trace4, trace5]
fig = go.Figure(data = data)
iplot(fig, filename='line-mode')

# %%
trace6 = go.Bar(
    x=df.loc[df['Year'] == '2010']['Category'],
    y=df.loc[df['Year'] == '2010']['IncidntNum_Count'],
    name='2010'
)

data = [trace1, trace2, trace3, trace4, trace5, trace6]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='stacked-bar')

# %%
[[]]*10
# Out:
# [[], [], [], [], [], [], [], [], [], []]

# %%
data = []
# years = df['Year'].drop_duplicates()
# for state in df['Origin_state'].drop_duplicates():
#     for i in range(len(years)):
#         data[i].append(go.Bar(x=df[(df['Origin_state'] == state) & (df['Year'] == years[i])]['Origin_city'].values.tolist(),
#                             y=df[(df['Origin_state'] == state) & (df['Year'] == years[i])]['Passengers'].values.tolist(),
#                             name= state,
#                            visible=False,
#                             ))


data1 = []
data2 = []
for state in df['Origin_state'].drop_duplicates():
    data.append(go.Bar(x=df[(df['Origin_state'] == state)]['Origin_city'].values.tolist(),
                        y=df[(df['Origin_state'] == state)]['Passengers'].values.tolist(),
                        name= state,
                       visible=False,
                        ))

buttons = []

for row, state in df.Origin_state.drop_duplicates().reset_index()['Origin_state'].iteritems():
    condition = [False]*len(df.Origin_state.drop_duplicates())
    condition[row] = True
    buttons.append(dict(label = state,
                 method = 'update',
                 args = [{'visible': condition},
                         {'title': 'Avg travelling population by city in : ' + state,
                          }]))

updatemenus=list([
    dict(
        buttons = buttons,
        pad = {'r': 0, 't': 10},
        #x = 0.1,
        #xanchor = 'left',
       # y = 1.0,
        yanchor = 'top',
        bgcolor = 'AAAAAA',
        active = 99,
        bordercolor = '#FFFFFF',
        font = dict(size=11, color='#000000'))])

layout = dict(title='Average travelling population by city', showlegend=False,
              updatemenus=updatemenus)

figure = dict(data=data, layout=layout)
#plotly.offline.plot(figure)
iplot(figure)
# Out:
# <div id="e240157d-9ffc-419f-8415-05b248fa71c9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e240157d-9ffc-419f-8415-05b248fa71c9", [{"type": "bar", "x": ["Anchorage", "Fairbanks", "Juneau", "Ketchikan", "Kodiak"], "y": [146458.11666666667, 30343.366666666665, 19624.366666666665, 13099.966666666667, 4814.9], "name": "AK", "visible": false}, {"type": "bar", "x": ["Anniston", "Auburn", "Birmingham", "Decatur", "Dothan", "Gadsden", "Huntsville", "Mobile", "Montgomery", "Selma", "Talladega", "Tuscaloosa"], "y": [96.75, 3.0, 135837.86666666667, 0.0, 4693.358333333334, 0.0, 44791.98333333333, 25430.666666666668, 15387.608333333334, 0.0, 0.0, 139.85882352941175], "name": "AL", "visible": false}, {"type": "bar", "x": ["Batesville", "Blytheville", "El Dorado", "Fayetteville", "Fort Smith", "Harrison", "Ho
# ...

# %%
data = []
# years = df['Year'].drop_duplicates()
# for state in df['Origin_state'].drop_duplicates():
#     for i in range(len(years)):
#         data[i].append(go.Bar(x=df[(df['Origin_state'] == state) & (df['Year'] == years[i])]['Origin_city'].values.tolist(),
#                             y=df[(df['Origin_state'] == state) & (df['Year'] == years[i])]['Passengers'].values.tolist(),
#                             name= state,
#                            visible=False,
#                             ))


data1 = []
data2 = []
for state in df['Origin_state'].drop_duplicates():
    data1.append(go.Bar(x=df[(df['Origin_state'] == state)]['Origin_city'].values.tolist(),
                        y=df[(df['Origin_state'] == state)]['Passengers'].values.tolist(),
                        name= state,
                       visible=False,
                        ))
for state in df2['Destination_state'].drop_duplicates():
    data2.append(go.Bar(x=df2[(df2['Destination_state'] == state)]['Destination_city'].values.tolist(),
                        y=df2[(df2['Destination_state'] == state)]['Passengers'].values.tolist(),
                        name= state,
                       visible=False,
                        ))

buttons = []

for row, state in df.Origin_state.drop_duplicates().reset_index()['Origin_state'].iteritems():
    condition1 = [False]*len(df.Origin_state.drop_duplicates())
    condition1[row] = True
#     condition2 = [False]*len(df.Origin_state.drop_duplicates())
#     condition2[row] = True
    buttons.append(dict(label = state,
                 method = 'update',
                 args = [{'visible': condition1},
                         {'title': 'Avg travelling population by city in : ' + state,
                          }]))

updatemenus=list([
    dict(
        buttons = buttons,
        pad = {'r': 0, 't': 10},
        #x = 0.1,
        #xanchor = 'left',
       # y = 1.0,
        yanchor = 'top',
        bgcolor = 'AAAAAA',
        active = 99,
        bordercolor = '#FFFFFF',
        font = dict(size=11, color='#000000'))])

layout = dict(title='Average travelling population by city', showlegend=False,
              updatemenus=updatemenus)

figure = dict(data=[data1, data2], layout=layout)
#plotly.offline.plot(figure)
iplot(figure)
# Out:
# ---------------------------------------------------------------------------
# PlotlyListEntryError                      Traceback (most recent call last)
# ~/anaconda/envs/fv/lib/python3.6/site-packages/plotly/tools.py in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1453         try:
# -> 1454             graph_objs.Figure(figure)
#    1455         except exceptions.PlotlyError as err:
#
# ~/anaconda/envs/fv/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#    1173     def __init__(self, *args, **kwargs):
# -> 1174         super(Figure, self).__init__(*args, **kwargs)
#    1175         if 'data' not in self:
#
# ~/anaconda/envs/fv/lib/python3.6/site-packages/plotly/graph_objs/graph_objs.py in __init__(self, *args, **kwargs)
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
#
# ...

# %%
data = [data1, data2]
layout = go.Layout(
)

fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# PlotlyListEntryError                      Traceback (most recent call last)
# <ipython-input-8-b806eae0d774> in <module>()
#       3 )
#       4
# ----> 5 fig = go.Figure(data=data, layout=layout)
#       6 iplot(fig)
#
# /Users/leesa/anaconda/lib/python2.7/site-packages/plotly/graph_objs/graph_objs.pyc in __init__(self, *args, **kwargs)
#    1161
#    1162     def __init__(self, *args, **kwargs):
# -> 1163         super(Figure, self).__init__(*args, **kwargs)
#    1164         if 'data' not in self:
#    1165             self.data = Data(_parent=self, _parent_key='data')
#
# /Users/leesa/anaconda/lib/python2.7/site-packages/plotly/graph_objs/graph_objs.pyc in __init__(self, *args, **kwargs)
#     375         d = {key: val for key, val in dict(*args, **kwargs).items()}
#     376         for key, val in d.items():
# --> 377             self.__setitem__(key, val, _raise=_raise)
#     378
# ...
